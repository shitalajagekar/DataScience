# %%
import requests as rq

# %%
raw_content=rq.get("https://en.wikipedia.org/wiki/Special:Random")

# %%
content=raw_content.text
print(content)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Pat Metheny Group (album) - Wikipedia</title>
# ...

# %%
title_start=content.find("<title>")
print(title_start)
# Out:
# 94

# %%
title_end=content.find("</title>")
t=len(" - Wikipedia")
print(title_end)
# Out:
# 138

# %%
title=content[94+len("<title>"):title_end-t]
print(title)
# Out:
# Pat Metheny Group (album)

# %%
from IPython.display import Image as IPythonImage
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont

# %%
album_raw=rq.get('https://picsum.photos/500/500/?random')
with open('image.png','wb')as raw_file:
    raw_file.write(album_raw.content)

from IPython.display import Image as IPythonImage
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont

img=Image.open('image.png')
draw=ImageDraw.Draw(img)
#font = ImageFont.load("arial.ttf")
#draw.text((50,50),title,font=font)
draw.text((20,20),title,(250,250,250))
img.save('text_image.png')
IPythonImage(filename='text_image.png')
