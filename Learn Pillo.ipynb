# %%
import requests as rq

# %%
album_raw=rq.get('https://picsum.photos/500/500/?random')
with open('image.png','wb')as raw_file:
    
    raw_file.write(album_raw.content)

# %%
from IPython.display import Image as IPythonImage
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont

# %%
# !ls
# Out:
# Example1.txt  example2.txt  example3.txt  image.png  quote.txt	text_image.png

# %%
img=Image.open("image.png")

# %%
IPythonImage(filename='image.png')

# %%
img=Image.open('image.png')
draw=ImageDraw.Draw(img)
draw.text((0,0),"Hello World",(255,255,255))
img.save('text_image.png')
IPythonImage(filename='text_image.png')

# %%
font=ImageFont.truetype("sans-serif.ttf",20)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-48-86e809504978> in <module>()
# ----> 1 font=ImageFont.truetype("sans-serif.ttf",20)
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     257
#     258     try:
# --> 259         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     260     except IOError:
#     261         ttf_filename = os.path.basename(font)
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     141
#     142         if isPath(font):
# --> 143             self.font = core.getfont(font, size, index, encoding, layout_engine=layout_engine)
#     144         else:
#     145             self.font_bytes = font.read()
#
# OSError: cannot open resource

# %%
# !wget -O sans-serif.ttf https://github.com/potyt/fonts/raw/master/macfonts/Microsoft%20Sans%20Serif/Microsoft%20Sans%20Serif.ttf
# Out:
# --2019-03-17 13:43:24--  https://github.com/potyt/fonts/raw/master/macfonts/Microsoft%20Sans%20Serif/Microsoft%20Sans%20Serif.ttf
# Resolving github.com (github.com)... 192.30.253.113, 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/potyt/fonts/master/macfonts/Microsoft%20Sans%20Serif/Microsoft%20Sans%20Serif.ttf [following]
# --2019-03-17 13:43:25--  https://raw.githubusercontent.com/potyt/fonts/master/macfonts/Microsoft%20Sans%20Serif/Microsoft%20Sans%20Serif.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.48.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.48.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 652248 (637K) [application/octet-stream]
# Saving to: ‘sans-serif.ttf’
#
# ...

# %%
font=ImageFont.truetype("sans-serif.ttf",20)

# %%
img=Image.open('image.png')
draw=ImageDraw.Draw(img)
draw.text((50,40),"Hello World",(255,255,255),font=font)
img.save('text_image.png')
IPythonImage(filename='text_image.png')
